# %%
import pandas as pd 
from os import listdir as ls 
ls()
season_games_overview = pd.concat(pd.read_parquet('[2019, 2020].parquet.gzip'), pd.read_parquet('[2021, 2022].parquet.gzip'))
season_games_overview
# Out:
# /var/folders/yr/ck3hvtw16ks5djc79x7fgf6r0000gn/T/ipykernel_74360/2814321517.py:4: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   season_games_overview = pd.concat(pd.read_parquet('[2019, 2020].parquet.gzip'), pd.read_parquet('[2021, 2022].parquet.gzip'))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 from os import listdir as ls
#       3 ls()
# ----> 4 season_games_overview = pd.concat(pd.read_parquet('[2019, 2020].parquet.gzip'), pd.read_parquet('[2021, 2022].parquet.gzip'))
#       5 season_games_overview
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
# pd.read_parquet('[2021, 2022]_game_stats.parquet-4.gzip')
pd.read_parquet('[2019, 2020].parquet.gzip')
# Out:
#       season               date away_team_id home_team_id  \
# 0       2019  Tue, Oct 16, 2018          PHI          BOS
# 1       2019  Tue, Oct 16, 2018          OKC          GSW
# 2       2019  Wed, Oct 17, 2018          MIL          CHO
# 3       2019  Wed, Oct 17, 2018          BRK          DET
# 4       2019  Wed, Oct 17, 2018          MEM          IND
# ...      ...                ...          ...          ...
# 2196    2020  Tue, Mar 10, 2020          LAC          GSW
# 2197    2020  Wed, Mar 11, 2020          DET          PHI
# 2198    2020  Wed, Mar 11, 2020          NYK          ATL
# 2199    2020  Wed, Mar 11, 2020          CHO          MIA
# 2200    2020  Wed, Mar 11, 2020          DEN          DAL
#
#                          arena                          link
# 0                    TD Garden  /boxscores/201810160BOS.html
# 1                 Oracle Arena  /boxscores/201810160GSW.html
# 2              Spectrum Center  /boxscores/201810170CHO.html
# ...
