# %%
import pandas as pd 
from os import listdir as ls 
ls()
pd.read_parquet('[2021, 2022].parquet.gzip')
# Out:
#       season               date away_team_id home_team_id  \
# 0       2021  Tue, Dec 22, 2020          GSW          BRK
# 1       2021  Tue, Dec 22, 2020          LAC          LAL
# 2       2021  Wed, Dec 23, 2020          CHO          CLE
# 3       2021  Wed, Dec 23, 2020          NYK          IND
# 4       2021  Wed, Dec 23, 2020          MIA          ORL
# ...      ...                ...          ...          ...
# 2219    2022  Wed, Apr 27, 2022          DEN          GSW
# 2220    2022  Thu, Apr 28, 2022          PHI          TOR
# 2221    2022  Thu, Apr 28, 2022          PHO          NOP
# 2222    2022  Thu, Apr 28, 2022          DAL          UTA
# 2223    2022  Fri, Apr 29, 2022          MEM          MIN
#
#                            arena                          link
# 0                Barclays Center  /boxscores/202012220BRK.html
# 1                 STAPLES Center  /boxscores/202012220LAL.html
# 2     Rocket Mortgage Fieldhouse  /boxscores/202012230CLE.html
# ...

# %%
pd.read_parquet('[2021, 2022]_game_stats.parquet-4.gzip')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pd.read_parquet('[2021, 2022]_game_stats.parquet-4.gzip')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parquet.py:503, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     456 """
#     457 Load a parquet object from the file path, returning a DataFrame.
#     458
#    (...)
#     499 DataFrame
#     500 """
#     501 impl = get_engine(engine)
# --> 503 return impl.read(
#     504     path,
#     505     columns=columns,
#     506     storage_options=storage_options,
#     507     use_nullable_dtypes=use_nullable_dtypes,
#     508     **kwargs,
#     509 )
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parquet.py:244, in PyArrowImpl.read(self, path, columns, use_nullable_dtypes, storage_options, **kwargs)
# ...
